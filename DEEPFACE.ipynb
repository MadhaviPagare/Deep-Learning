# %%
pip install deepface
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# ...
#
# ...
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115943 sha256=8353a99718c783f87576c46926cf0c867cfe70262cd435ff56f6f078f55f33f8
#   Stored in directory: c:\users\madhavi\appdata\local\pip\cache\wheels\2a\93\86\8cd17bc6c40fb605c3ac549d0b860ef7e84ee5f67bf01a3287
# ...
#   Created wheel for gdown: filename=gdown-4.5.1-py3-none-any.whl size=14933 sha256=410f6adc169e016af83cad87186baf3bffed47a899ed9b35dcafc79691d017e9
#   Stored in directory: c:\users\madhavi\appdata\local\pip\cache\wheels\b8\79\f0\b523d25d96b0bbb12bb024b97940d08c4fcd498a00070c8d82
# Successfully built fire gdown
# ...

# %%
from deepface import DeepFace
import cv2
import matplotlib.pyplot as plt
img_path = 'Madhavi.jpg'
img = cv2.imread(img_path)
plt.imshow(img[:, :,::-1])
# Out:
# Directory  C:\Users\MADHAVI /.deepface created
# Directory  C:\Users\MADHAVI /.deepface/weights created

# %%
demography = DeepFace.analyze(img_path)
demography
# Out:
# facial_expression_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: C:\Users\MADHAVI\.deepface\weights\facial_expression_model_weights.h5
# 100%|█████████████████████████████████████████████████████████████████████████████| 5.98M/5.98M [00:00<00:00, 7.94MB/s]
# age_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5
# To: C:\Users\MADHAVI\.deepface\weights\age_model_weights.h5
# 100%|███████████████████████████████████████████████████████████████████████████████| 539M/539M [00:42<00:00, 12.6MB/s]
# gender_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/gender_model_weights.h5
# To: C:\Users\MADHAVI\.deepface\weights\gender_model_weights.h5
# ...

# %%
demography['emotion']
# Out:
# {'angry': 3.1272763043474334e-05,
#  'disgust': 2.7438039787099664e-12,
#  'fear': 1.4192817503413585e-07,
#  'happy': 99.66721530761902,
#  'sad': 0.00017605757245857433,
#  'surprise': 1.0979719776636403e-05,
#  'neutral': 0.332566856004817}

# %%
demography['dominant_emotion']
# Out:
# 'happy'
