# %%
import cv2
from fer import FER
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
input_image = cv2.imread("C:/Users/MADHAVI/Downloads/expression project/bounding_box/group.jpeg")
emotion_detector = FER(mtcnn=True)

# %%
# Save output in result variable
result = emotion_detector.detect_emotions(input_image)
result
# Out:
# WARNING:tensorflow:5 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000014CEA156790> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...

# %%
bounding_box = result[0]["box"]
emotions = result[0]["emotions"]
cv2.rectangle(input_image,(
  bounding_box[0], bounding_box[1]),(
  bounding_box[0] + bounding_box[2], bounding_box[1] + bounding_box[3]),
              (0, 155, 255), 2,)
# Out:
# array([[[137, 160, 179],
#         [137, 160, 179],
#         [136, 159, 178],
#         ...,
#         [147, 162, 171],
#         [152, 169, 178],
#         [158, 175, 184]],
#
#        [[137, 160, 179],
#         [137, 160, 179],
#         [137, 160, 179],
#         ...,
#         [154, 169, 178],
#         [154, 172, 180],
#         [153, 171, 179]],
#
#        [[139, 162, 181],
#         [139, 162, 181],
#         [139, 162, 181],
#         ...,
#         [161, 176, 185],
#         [157, 174, 183],
#         [139, 157, 165]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
bounding_box = result[1]["box"]
emotions = result[0]["emotions"]
cv2.rectangle(input_image,(bounding_box[3], bounding_box[3]),(bounding_box[2] + bounding_box[3], bounding_box[1] + bounding_box[3]),(0, 255, 255), 2,)
# Out:
# array([[[137, 160, 179],
#         [137, 160, 179],
#         [136, 159, 178],
#         ...,
#         [147, 162, 171],
#         [152, 169, 178],
#         [158, 175, 184]],
#
#        [[137, 160, 179],
#         [137, 160, 179],
#         [137, 160, 179],
#         ...,
#         [154, 169, 178],
#         [154, 172, 180],
#         [153, 171, 179]],
#
#        [[139, 162, 181],
#         [139, 162, 181],
#         [139, 162, 181],
#         ...,
#         [161, 176, 185],
#         [157, 174, 183],
#         [139, 157, 165]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
emotion_name, score = emotion_detector.top_emotion(input_image)
for index, (emotion_name, score) in enumerate(emotions.items()):
   color = (211, 211,211) if score < 0.01 else (255, 0, 0)
   emotion_score = "{}: {}".format(emotion_name, "{:.2f}".format(score))
 
   cv2.putText(input_image,emotion_score,
               (bounding_box[0], bounding_box[1] + bounding_box[3] + 30 + index * 15),
               cv2.FONT_HERSHEY_SIMPLEX,0.5,color,1,cv2.LINE_AA,)
 
#Save the result in new image file
cv2.imwrite("C:/Users/MADHAVI/Downloads/expression project/bounding_box/groupResult.jpeg", input_image)
# Out:
# True

# %%
# Read image file using matplotlib's image module
result_image = mpimg.imread('C:/Users/MADHAVI/Downloads/expression project/bounding_box/groupResult.jpeg')
imgplot = plt.imshow(result_image)
# Display Output Image
plt.show()

# %%
# Use the top Emotion() function to call for the dominant emotion in the image
dominant_emotion, emotion_score = emotion_detector.top_emotion(input_image)
print(dominant_emotion, emotion_score)
# Out:
# happy 0.99
