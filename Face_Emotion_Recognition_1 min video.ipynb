# %%
# Working on the same concept with videos as input
# Import the necessary FER() packages for Video Processing

# %%
pip install FER
# Out:
# Requirement already satisfied: FER in c:\users\madhavi\anaconda3\lib\site-packages (22.4.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: requests in c:\users\madhavi\anaconda3\lib\site-packages (from FER) (2.26.0)
# Requirement already satisfied: matplotlib in c:\users\madhavi\anaconda3\lib\site-packages (from FER) (3.4.3)
# Requirement already satisfied: keras>=2.0.0 in c:\users\madhavi\anaconda3\lib\site-packages (from FER) (2.8.0)
# Requirement already satisfied: opencv-contrib-python in c:\users\madhavi\anaconda3\lib\site-packages (from FER) (4.6.0.66)
# Requirement already satisfied: mtcnn>=0.1.1 in c:\users\madhavi\anaconda3\lib\site-packages (from FER) (0.1.1)
# Requirement already satisfied: tqdm in c:\users\madhavi\anaconda3\lib\site-packages (from FER) (4.62.3)
# Requirement already satisfied: opencv-python>=4.1.0 in c:\users\madhavi\anaconda3\lib\site-packages (from mtcnn>=0.1.1->FER) (4.5.5.64)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\madhavi\anaconda3\lib\site-packages (from opencv-python>=4.1.0->mtcnn>=0.1.1->FER) (1.20.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\madhavi\anaconda3\lib\site-packages (from matplotlib->FER) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\madhavi\anaconda3\lib\site-packages (from matplotlib->FER) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\madhavi\anaconda3\lib\site-packages (from matplotlib->FER) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\madhavi\anaconda3\lib\site-packages (from matplotlib->FER) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\madhavi\anaconda3\lib\site-packages (from matplotlib->FER) (2.8.2)
# Requirement already satisfied: six in c:\users\madhavi\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib->FER) (1.16.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\madhavi\anaconda3\lib\site-packages (from requests->FER) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\madhavi\anaconda3\lib\site-packages (from requests->FER) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\madhavi\anaconda3\lib\site-packages (from requests->FER) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\madhavi\anaconda3\lib\site-packages (from requests->FER) (3.2)
# Requirement already satisfied: colorama in c:\users\madhavi\anaconda3\lib\site-packages (from tqdm->FER) (0.4.4)

# %%
from fer import Video
from fer import FER
import os
import sys
import pandas as pd
# Put in the location of the video file that has to be processed
location_videofile = "C:/Users/MADHAVI/Downloads/expression project/Emotion Recognition using Live Video/INPUT/Video_Three.mp4"

# %%
# But the Face detection detector
face_detector = FER(mtcnn=True)
# Input the video for processing
input_video = Video(location_videofile)

# %%
# The Analyze() function will run analysis on every frame of the input video. 
# It will create a rectangular box around every image and show the emotion values next to that.
# Finally, the method will publish a new video that will have a box around the face of the human with live emotion values.
processing_data = input_video.analyze(face_detector, display=False)
# Out:
# INFO:fer:30.00 fps, 2380 frames, 79.33 seconds
# INFO:fer:Making directories at output
#  98%|████████████████████████████████████████████████████████████████████████▋ | 2339/2380 [48:17<00:58,  1.43s/frames]

# %%
# We will now convert the analysed information into a dataframe.
# This will help us import the data as a .CSV file to perform analysis over it later
vid_df = input_video.to_pandas(processing_data)
vid_df = input_video.get_first_face(vid_df)
vid_df = input_video.get_emotions(vid_df)

# Plotting the emotions against time in the video
pltfig = vid_df.plot(figsize=(20, 8), fontsize=16).get_figure()

# %%
# We will now work on the dataframe to extract which emotion was prominent in the video
angry = sum(vid_df.angry)
disgust = sum(vid_df.disgust)
fear = sum(vid_df.fear)
happy = sum(vid_df.happy)
sad = sum(vid_df.sad)
surprise = sum(vid_df.surprise)
neutral = sum(vid_df.neutral)
#length_df=angry+disgust+happy+sad+surprise+neutral
len(vid_df)

# %%
emotions = ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']
emotions_values = [(angry/len(vid_df)), (disgust/len(vid_df)), (fear/len(vid_df)),(happy/len(vid_df)),( sad/len(vid_df)), (surprise/len(vid_df)),(neutral/len(vid_df))]

score_comparisons = pd.DataFrame(emotions, columns = ['Human Emotions'])
score_comparisons['Emotion Value from the Video'] = emotions_values
score_comparisons

# %%
# We will conclude the project by experimenting the code on another video
location_videofile_two = "C:/Users/MADHAVI/Downloads/expression project/Emotion Recognition using Live Video/INPUT/Video_Two.mp4"
input_video_two = Video(location_videofile_two)
processing_data_two = input_video_two.analyze(face_detector, display=False)

vid_df_2 = input_video_two.to_pandas(processing_data_two)
vid_df_2 = input_video_two.get_first_face(vid_df_2)
vid_df_2 = input_video_two.get_emotions(vid_df_2)

pltfig = vid_df_2.plot(figsize=(20, 8), fontsize=16).get_figure()
# Out:
# INFO:fer:30.00 fps, 458 frames, 15.27 seconds
# INFO:fer:Making directories at output
# 100%|████████████████████████████████████████████████████████████████████████████| 458/458 [15:39<00:00,  2.05s/frames]
# INFO:fer:Completed analysis: saved to output\Video_Two_output.mp4
# INFO:fer:Starting to Zip
# INFO:fer:Compressing: 10%
# INFO:fer:Compressing: 21%
# INFO:fer:Compressing: 32%
# INFO:fer:Compressing: 43%
# INFO:fer:Compressing: 54%
# INFO:fer:Compressing: 65%
# INFO:fer:Compressing: 76%
# INFO:fer:Compressing: 87%
# INFO:fer:Compressing: 98%
# INFO:fer:Zip has finished

# %%
angry_2 = sum(vid_df_2.angry)
disgust_2 = sum(vid_df_2.disgust)
fear_2 = sum(vid_df_2.fear)
happy_2 = sum(vid_df_2.happy)
sad_2 = sum(vid_df_2.sad)
surprise_2 = sum(vid_df_2.surprise)
neutral_2 = sum(vid_df_2.neutral)

emotions_values_2 = [angry_2, disgust_2, fear_2, happy_2, sad_2, surprise_2, neutral_2]
score_comparisons = pd.DataFrame(emotions, columns = ['Human Emotions'])
score_comparisons['Emotion Value from the Video'] = emotions_values_2
score_comparisons
# Out:
#   Human Emotions  Emotion Value from the Video
# 0          Angry                         21.91
# 1        Disgust                          0.00
# 2           Fear                         32.44
# 3          Happy                        137.58
# 4            Sad                         81.91
# 5       Surprise                         13.09
# 6        Neutral                        170.72
