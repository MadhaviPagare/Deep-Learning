# %%
pip install fer
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from fer import FER
import matplotlib.pyplot as plt 
# %matplotlib inline

test_image_one = plt.imread("C:/Users/MADHAVI/Downloads/expression project/Image-One.jpeg")
emo_detector = FER(mtcnn=True)
# Capture all the emotions on the image
captured_emotions = emo_detector.detect_emotions(test_image_one)
# Print all captured emotions with the image
print(captured_emotions)
plt.imshow(test_image_one)
# Out:
# WARNING:tensorflow:5 out of the last 495 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002C81A961430> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...

# %%
# Use the top Emotion() function to call for the dominant emotion in the image
dominant_emotion, emotion_score = emo_detector.top_emotion(test_image_one)
print(dominant_emotion, emotion_score)
# Out:
# neutral 0.97

# %%
# We repeat the same steps for a few other images to confirm the performance of FER()
test_image_two = plt.imread("C:/Users/MADHAVI/Downloads/expression project/Image-Two.jpg")
captured_emotions_two = emo_detector.detect_emotions(test_image_two)
print(captured_emotions_two)
plt.imshow(test_image_two)
# Out:
# [{'box': [46, 48, 78, 110], 'emotions': {'angry': 0.0, 'disgust': 0.0, 'fear': 0.0, 'happy': 0.98, 'sad': 0.0, 'surprise': 0.0, 'neutral': 0.01}}]

# %%
dominant_emotion_two, emotion_score_two = emo_detector.top_emotion(test_image_two)
print(dominant_emotion_two, emotion_score_two)
# Out:
# happy 0.98

# %%
# Testing on another image
test_image_three = plt.imread("C:/Users/MADHAVI/Downloads/expression project/Image-Three.jpg")
captured_emotions_three = emo_detector.detect_emotions(test_image_three)
print(captured_emotions_three)
plt.imshow(test_image_three)
# Out:
# [{'box': [261, 193, 463, 676], 'emotions': {'angry': 0.0, 'disgust': 0.0, 'fear': 0.0, 'happy': 0.58, 'sad': 0.02, 'surprise': 0.0, 'neutral': 0.4}}]

# %%
dominant_emotion_three, emotion_score_three = emo_detector.top_emotion(test_image_three)
print(dominant_emotion_three, emotion_score_three)
# Out:
# happy 0.58

# %%
# Testing on another image
test_image_four = plt.imread("C:/Users/MADHAVI/Downloads/expression project/Image-Four.jpg")
captured_emotions_four = emo_detector.detect_emotions(test_image_four)
print(captured_emotions_four)
plt.imshow(test_image_four)
# Out:
# [{'box': [169, 75, 199, 237], 'emotions': {'angry': 0.78, 'disgust': 0.0, 'fear': 0.14, 'happy': 0.0, 'sad': 0.03, 'surprise': 0.01, 'neutral': 0.04}}]

# %%
dominant_emotion_four, emotion_score_four = emo_detector.top_emotion(test_image_four)
print(dominant_emotion_four, emotion_score_four)
# Out:
# angry 0.78

# %%
# Testing on another image
test_image_five = plt.imread("C:/Users/MADHAVI/Downloads/expression project/Madhavi.jpg")
captured_emotions_five = emo_detector.detect_emotions(test_image_five)
print(captured_emotions_five)
plt.imshow(test_image_five)
# Out:
# [{'box': [704, 552, 886, 1164], 'emotions': {'angry': 0.0, 'disgust': 0.0, 'fear': 0.0, 'happy': 0.99, 'sad': 0.0, 'surprise': 0.0, 'neutral': 0.01}}]

# %%
dominant_emotion_five, emotion_score_five = emo_detector.top_emotion(test_image_five)
print(dominant_emotion_five, emotion_score_five)
# Out:
# happy 0.99

# %%
# Testing on another image
test_image_four1 = plt.imread("C:/Users/MADHAVI/Downloads/expression project/abcd.jpg")
captured_emotions_four1 = emo_detector.detect_emotions(test_image_four1)
print(captured_emotions_four1)
plt.imshow(test_image_four1)
# Out:
# [{'box': [259, 91, 97, 141], 'emotions': {'angry': 0.92, 'disgust': 0.0, 'fear': 0.0, 'happy': 0.08, 'sad': 0.0, 'surprise': 0.0, 'neutral': 0.0}}]

# %%
dominant_emotion_four1, emotion_score_four1 = emo_detector.top_emotion(test_image_four1)
print(dominant_emotion_four1, emotion_score_four1)
# Out:
# angry 0.92

# %%
# Testing on another image
test_image_four11 = plt.imread("C:/Users/MADHAVI/Downloads/expression project/pqrs.jpg")
captured_emotions_four11 = emo_detector.detect_emotions(test_image_four11)
print(captured_emotions_four11)
plt.imshow(test_image_four11)
# Out:
# [{'box': [546, 0, 871, 1014], 'emotions': {'angry': 0.01, 'disgust': 0.0, 'fear': 0.44, 'happy': 0.0, 'sad': 0.0, 'surprise': 0.55, 'neutral': 0.0}}]

# %%
dominant_emotion_four11, emotion_score_four11 = emo_detector.top_emotion(test_image_four11)
print(dominant_emotion_four11, emotion_score_four11)
# Out:
# surprise 0.55

# %%
# Testing on another image
test_image_four1111 = plt.imread("C:/Users/MADHAVI/Downloads/expression project/istockphoto-184625367-612x612.jpg")
captured_emotions_four1111 = emo_detector.detect_emotions(test_image_four1111)
print(captured_emotions_four1111)
plt.imshow(test_image_four1111)
# Out:
# [{'box': [170, 68, 173, 247], 'emotions': {'angry': 0.32, 'disgust': 0.05, 'fear': 0.59, 'happy': 0.01, 'sad': 0.0, 'surprise': 0.02, 'neutral': 0.0}}]

# %%
dominant_emotion_four1111, emotion_score_four1111 = emo_detector.top_emotion(test_image_four1111)
print(dominant_emotion_four1111, emotion_score_four1111)
# Out:
# fear 0.59

# %%
# Testing on another image
test_image_four11111 = plt.imread("C:/Users/MADHAVI/Downloads/expression project/eeeee.jpg")
captured_emotions_four11111 = emo_detector.detect_emotions(test_image_four11111)
print(captured_emotions_four11111)
plt.imshow(test_image_four11111)
# Out:
# [{'box': [136, 36, 257, 337], 'emotions': {'angry': 0.11, 'disgust': 0.0, 'fear': 0.05, 'happy': 0.0, 'sad': 0.83, 'surprise': 0.0, 'neutral': 0.01}}]

# %%
dominant_emotion_four11111, emotion_score_four11111 = emo_detector.top_emotion(test_image_four11111)
print(dominant_emotion_four11111, emotion_score_four11111)
# Out:
# sad 0.83
