# %%
import cv2
from fer import FER
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
input_image = cv2.imread("group.jpeg")
emotion_detector = FER(mtcnn=True)

# %%
# Save output in result variable
result = emotion_detector.detect_emotions(input_image)
result
# Out:
# ---------------------------------------------------------------------------
# InvalidImage                              Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14504/802605802.py in <module>
#       1 # Save output in result variable
# ----> 2 result = emotion_detector.detect_emotions(input_image)
#       3 result
#
# ~\anaconda3\lib\site-packages\fer\fer.py in detect_emotions(self, img, face_rectangles)
#     235         :return: list containing all the bounding boxes detected with their emotions.
#     236         """
# --> 237         img = load_image(img)
#     238
#     239         emotion_labels = self._get_labels()
#
# ~\anaconda3\lib\site-packages\fer\utils.py in load_image(img)
#      56         is_exact_image = True
#      57     elif img is None:
# ---> 58         raise InvalidImage("Image not valid.")
#      59     elif len(img) > 11 and img[0:11] == "data:image/":
#      60         is_base64_img = True
#
# InvalidImage: Image not valid.

# %%
bounding_box = result[0]["box"]
emotions = result[0]["emotions"]
cv2.rectangle(input_image,(
  bounding_box[0], bounding_box[1]),(
  bounding_box[0] + bounding_box[2], bounding_box[1] + bounding_box[3]),
              (0, 155, 255), 2,)
# Out:
# array([[[134, 159, 179],
#         [134, 159, 179],
#         [134, 160, 177],
#         ...,
#         [145, 162, 171],
#         [152, 169, 178],
#         [156, 173, 182]],
#
#        [[137, 162, 182],
#         [136, 161, 181],
#         [136, 162, 179],
#         ...,
#         [151, 168, 177],
#         [157, 174, 183],
#         [152, 169, 178]],
#
#        [[138, 164, 181],
#         [136, 162, 179],
#         [136, 162, 179],
#         ...,
#         [157, 174, 183],
#         [158, 175, 184],
#         [139, 156, 165]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)

# %%
#bounding_box = result[0]["box"]
#emotions = result[0]["emotions"]
#cv2.rectangle(input_image,(
#  bounding_box[3], bounding_box[3]),(
 # bounding_box[2] + bounding_box[3], bounding_box[1] + bounding_box[3]),
  #            (0, 255, 255), 2,)

# %%
emotion_name, score = emotion_detector.top_emotion(input_image)
for index, (emotion_name, score) in enumerate(emotions.items()):
   color = (211, 211,211) if score < 0.01 else (255, 0, 0)
   emotion_score = "{}: {}".format(emotion_name, "{:.2f}".format(score))
 
   cv2.putText(input_image,emotion_score,
               (bounding_box[0], bounding_box[1] + bounding_box[3] + 30 + index * 15),
               cv2.FONT_HERSHEY_SIMPLEX,0.5,color,1,cv2.LINE_AA,)
 
#Save the result in new image file
cv2.imwrite("group.jpeg", input_image)
# Out:
# True

# %%
# Read image file using matplotlib's image module
result_image = mpimg.imread('group.jpeg')
imgplot = plt.imshow(result_image)
# Display Output Image
plt.show()

# %%
# Use the top Emotion() function to call for the dominant emotion in the image
dominant_emotion, emotion_score = emotion_detector.top_emotion(input_image)
print(dominant_emotion, emotion_score)
# Out:
# happy 0.89
